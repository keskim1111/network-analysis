# %%
import os
import numpy as np
os.chdir('..\\') # in ./tests folder - so changing to parent folder for imports

from consts import FOLDER2FLOW_RESULTS
import pandas as pd
import pprint
import matplotlib.pyplot as plt
from IPython.display import display

class df_extra:    
    def __init__(self, df):
        self.df = df
        self.num_rows = df.shape[0]
        self.data_dict = {}

    def add_data_to_df(self, col_name, data):
        self.data_dict[col_name] = [data]*self.num_rows
        self.df[col_name] = data

def create_united_df(date_folder, timelimit=0): # This is a df of all networks in folder
    res_dp = os.path.join(FOLDER2FLOW_RESULTS, date_folder)
    dfs_list = []
    for network in sorted(os.listdir(res_dp), reverse=True):
        df_fp = os.path.join(res_dp, network, "results.df")
        if network.endswith(".log") or not os.path.exists(df_fp):
            continue
        df = pd.read_pickle(df_fp)

        _df_extra = df_extra(df)
        _df_extra.add_data_to_df("network", network)
        _df_extra.add_data_to_df("mu", network.split("_")[1])

        dfs_list.append(df)
    df = pd.concat(dfs_list)
    df.reset_index(inplace=True)
    del df["index"]
    
    # replace names to shorter names for readabilty
    df["algo"].replace(f"NLP-100-TL-{timelimit}", "NLP100", inplace=True)
    df["algo"].replace(f"NLP-150-TL-{timelimit}", "NLP150", inplace=True)
    df["algo"].replace(f"NLP-200-TL-{timelimit}", "NLP200", inplace=True)
    
    return df

def prepare_data_for_plot(df):
    evals = ["avg_modularity", "std_modularity", "avg_jaccard", "std_jaccard"]
    mus = ["all", "0.4", "0.5", "0.6"]
    evals_dict = {}

    for mu in mus:
        evals_dict[mu] = {}
        for _eval in evals:
            evals_dict[mu][_eval] = {}

    for algo in df.algo.unique():
        for mu, evals in evals_dict.items():
    #         print(algo, mu)
            if mu == "all":
                algo_rows = df.loc[df["algo"]==algo]
            else:
                algo_rows = df.loc[df["algo"]==algo].loc[df["mu"]==mu]

            avg_modularity = algo_rows["modularity - algo"].mean()
            std_modularity = algo_rows["modularity - algo"].std()
            avg_jaccard = algo_rows["jaccard"].mean()
            std_jaccard = algo_rows["jaccard"].std()

            evals["avg_modularity"][algo] = avg_modularity
            evals["std_modularity"][algo] = std_modularity
            evals["avg_jaccard"][algo] = avg_jaccard
            evals["std_jaccard"][algo] = std_jaccard
    return evals_dict


def create_plots(data_for_plot):
    for mu, mu_evals in data_for_plot.items():
        for eval_name, eval_data in mu_evals.items():
            fig, ax = plt.subplots()
            ax.set_title(f'{eval_name}, mu={mu}')
            x = eval_data.values()
            y = eval_data.keys()
            ax.plot(y, x)
            ax.axhline(y=list(x)[1], color='r', linestyle='--')

            
# def run_visu(date_folder):
#     df = create_united_df(date_folder, timelimit=2400)
#     display(df)
#     data_for_plots = prepare_data_for_plot(df)
#     create_plots(data_for_plots)

def create_plot_all_mus(df, ev_col="modularity - algo", plot_name="modularity", num=0, path_to_save_figs=""):
#     mus = ["0.4", "0.5", "0.6"]
        
    fig, (ax1, ax2) = plt.subplots(1, 2)
#     fig2, ax2 = plt.subplots()
    ax1.set_title(f'{plot_name}-mean')
    ax2.set_title(f'{plot_name}-std')

    for algo in df.algo.unique():
        x = [] # mus
        y_mean = [] # evals per mu
        y_std = []
    
        # avg_modularity
        for mu in df.mu.unique():
#             print(f'{algo}, {mu}')
            algo_rows = df.loc[(df["mu"]==mu) & (df["algo"]==algo)]            
            algo_eval_rows = algo_rows[ev_col]
            y_mean.append(algo_eval_rows.mean())
            y_std.append(algo_eval_rows.std())
            x.append(mu)     
        ax1.plot(x, y_mean, label=f'{algo}')
        ax2.plot(x, y_std, label=f'{algo}')
#         print(algo, x,y_mean,y_std)
    ax1.legend()
    ax2.legend()
    fig.tight_layout()
#     path_to_save_figs = os.path.join()
    fig.savefig(os.path.join(path_to_save_figs, f'{plot_name}.png'), format="png")

    
def create_comparison_plot(df, ev_col="modularity - algo", plot_name="modularity", num=0, path_to_save_figs="", algo_index=0):
#     mus = ["0.4", "0.5", "0.6"]
        
    fig, (ax1, ax2) = plt.subplots(1, 2)
#     fig2, ax2 = plt.subplots()
    ax1.set_title(f'{plot_name}-mean')
    ax2.set_title(f'{plot_name}-std')

    for algo in df.algo.unique()[algo_index+1:]:
        x = [] # mus
        y_mean = [] # evals per mu
        y_std = []
    
        # avg_modularity
        for mu in df.mu.unique():
#             print(f'{algo}, {mu}')
            main_algo_rows = df.loc[(df["mu"]==mu) & (df["algo"]==df.algo.unique()[algo_index])]            
            new_algo_rows = df.loc[(df["mu"]==mu) & (df["algo"]==algo)]            
            main_algo_eval_rows = main_algo_rows[ev_col]
            new_algo_eval_rows = new_algo_rows[ev_col]

            y_mean.append(new_algo_eval_rows.mean()/main_algo_eval_rows.mean())
            y_std.append(new_algo_eval_rows.std()/main_algo_eval_rows.std())
            x.append(mu)     
        ax1.plot(x, y_mean, label=f'{algo}')
        ax2.plot(x, y_std, label=f'{algo}')
#         print(algo, x,y_mean,y_std)
    ax1.legend()
    ax2.legend()
    fig.tight_layout()
#     path_to_save_figs = os.path.join()
#     fig.savefig(os.path.join(path_to_save_figs, f'{plot_name}-compare'), format="png")
    
def create_graph(date_folder, ev_col="modularity - algo", plot_name="modularity", num=0):
    df = create_united_df(date_folder, timelimit=2400)
#     display(df)
    res_path = os.path.join(FOLDER2FLOW_RESULTS, date_folder, "figures")
    if not os.path.isdir(res_path):
        os.mkdir(res_path)
    create_plot_all_mus(df, ev_col, plot_name,  num, path_to_save_figs=res_path)
    return df

def get_avg_for_field(df, field):
    res_dict = {}
    for algo in df.algo.unique():
        for mu in df.mu.unique():
            if res_dict.get(algo) == None:
                res_dict[algo] = {}
            res_dict[algo][mu] = df.loc[(df["algo"]==algo) & (df["mu"]==mu)][field].mean()
            if field=="time-sec":
                res_dict[algo][mu] = res_dict[algo][mu]/60
        res_dict[algo]["all"] = sum(list(res_dict[algo].values()))/len(list(res_dict[algo].values()))
    return res_dict

def create_error_bars_plot(df, ev_col="modularity - algo", plot_name="modularity", num=0, path_to_save_figs=""):
        
#     fig, ax = plt.subplots()
#     fig2, ax2 = plt.subplots()
#     ax.set_title(f'{plot_name}-mean')

    for algo in df.algo.unique():
        x = [] # mus
        y_mean = [] # evals per mu
        y_std = []
    
        # avg_modularity
        for mu in df.mu.unique():
#             print(f'{algo}, {mu}')
            algo_rows = df.loc[(df["mu"]==mu) & (df["algo"]==algo)]            
            algo_eval_rows = algo_rows[ev_col]
            y_mean.append(algo_eval_rows.mean())
            y_std.append(algo_eval_rows.std())
            y_err = algo_eval_rows.std()
            x.append(mu)     
            plt.errorbar(x, y_mean, yerr=y_err)
            #https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
        print(algo)
        plt.show()
#         print(algo, x,y_mean,y_std)
#     plt.legend()
#     fig.tight_layout()
#     path_to_save_figs = os.path.join()
#     fig.savefig(os.path.join(path_to_save_figs, f'{plot_name}.png'), format="png")

# %%
date_folder = "17-05-2022--23-06-48-newman" 
df = create_graph(date_folder)
create_error_bars_plot(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-001114084bf6> in <module>
#       1 date_folder = "17-05-2022--23-06-48-newman"
#       2 df = create_graph(date_folder)
# ----> 3 create_error_bars_plot(df)
#
# <ipython-input-35-8d67939f0cb1> in create_error_bars_plot(df, ev_col, plot_name, num, path_to_save_figs)
#     196             y_err = algo_eval_rows.std()
#     197             x.append(mu)
# --> 198             x = np.linespace(x)
#     199             plt.errorbar(x, y_mean, yerr=y_err)
#     200         print(algo)
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     311                 return Tester
#     312
# --> 313             raise AttributeError("module {!r} has no attribute "
#     314                                  "{!r}".format(__name__, attr))
#     315
#
# AttributeError: module 'numpy' has no attribute 'linespace'

# %%
# date_folder = "17-05-2022--13-36-06"
# date_folder = "17-05-2022--23-06-48-newman"
# run_visu(date_folder)

# %% [markdown]
# - check if there is an issue with manual modularity - for newman (bc of minus in modularity that we saw...)
# - look at results: average of runtime, num_coms_divided over lp_criticals... decide if should run again with diff lp_criticals?
# - need to have same num of results per mu (lets say 5 results per mu)

# %% [markdown]
# # Newman: 1,000 nodes

# %%
date_folder = "17-05-2022--23-06-48-newman" 
df = create_graph(date_folder)
create_error_bars_plot(df)
create_comparison_plot(df, algo_index=1, plot_name="modularity: comparison")
df = create_graph(date_folder, ev_col="jaccard", plot_name="jaccard")
create_comparison_plot(df, algo_index=1, ev_col="jaccard", plot_name="jaccard: comparison")
df = create_graph(date_folder, ev_col="graph_accuracy", plot_name="graph_accuracy")
df = create_graph(date_folder, ev_col="graph_sensitivity", plot_name="graph_sensitivity")
df = create_graph(date_folder, ev_col="graph_conductance", plot_name="graph_conductance")
display(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-e59b20425b15> in <module>
#       1 date_folder = "17-05-2022--23-06-48-newman"
#       2 df = create_graph(date_folder)
# ----> 3 create_error_bars_plot(df)
#       4 create_comparison_plot(df, algo_index=1, plot_name="modularity: comparison")
#       5 df = create_graph(date_folder, ev_col="jaccard", plot_name="jaccard")
#
# <ipython-input-18-75a68a04deba> in create_error_bars_plot(df, ev_col, plot_name, num, path_to_save_figs)
#     197             y_err = algo_eval_rows.std()
#     198             x.append(mu)
# --> 199             plt.errorbar(x, y_mean, y_err=y_err)
#     200     plt.show()
#     201 #         print(algo, x,y_mean,y_std)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2602         uplims=False, xlolims=False, xuplims=False, errorevery=1,
#    2603         capthick=None, *, data=None, **kwargs):
# -> 2604     return gca().errorbar(
#    2605         x, y, yerr=yerr, xerr=xerr, fmt=fmt, ecolor=ecolor,
#    2606         elinewidth=elinewidth, capsize=capsize, barsabove=barsabove,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3355         data_line = None
#    3356         if plot_line:
# -> 3357             data_line = mlines.Line2D(x, y, **plot_line_style)
#    3358             self.add_line(data_line)
#    3359
#
# ~\anaconda3\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     388         # update kwargs before updating data to give the caller a
#     389         # chance to init axes (and hence unit support)
# --> 390         self.update(kwargs)
#     391         self.pickradius = pickradius
#     392         self.ind_offset = 0
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'y_err'

# %%
res_dict = get_avg_for_field(df, field="time-sec")
pprint.pprint(res_dict)
# Out:
# {'Louvain': {'0.4': 0.018942078611144098,
#              '0.5': 0.011742555000006785,
#              '0.6': 0.01938520666666702,
#              'all': 0.01668994675927263},
#  'NLP100': {'0.4': 13.656220676388854,
#             '0.5': 4.783381334166686,
#             '0.6': 5.00409804183335,
#             'all': 7.81456668412963},
#  'NLP150': {'0.4': 26.983584297222237,
#             '0.5': 15.02856996799995,
#             '0.6': 35.25026369700001,
#             'all': 25.754139320740734},
#  'NLP200': {'0.4': 56.19989329999998,
#             '0.5': 32.1831857005,
#             '0.6': 50.99254159783334,
#             'all': 46.458540199444435},
#  'Newman': {'0.4': 0.10543940333332608,
#             '0.5': 0.049760925333357596,
#             '0.6': 0.06323044116666957,
#             'all': 0.07281025661111774}}

# %%
res_dict = get_avg_for_field(df, field="num_coms_divided")
pprint.pprint(res_dict)
# Out:
# {'Louvain': {'0.4': nan, '0.5': nan, '0.6': nan, 'all': nan},
#  'NLP100': {'0.4': 11.666666666666666,
#             '0.5': 9.3,
#             '0.6': 1.4,
#             'all': 7.455555555555556},
#  'NLP150': {'0.4': 9.833333333333334,
#             '0.5': 8.8,
#             '0.6': 2.0,
#             'all': 6.877777777777777},
#  'NLP200': {'0.4': 5.333333333333333,
#             '0.5': 5.2,
#             '0.6': 1.1,
#             'all': 3.8777777777777778},
#  'Newman': {'0.4': nan, '0.5': nan, '0.6': nan, 'all': nan}}

# %% [markdown]
# # Louvain - 10,000 nodes

# %%
date_10000_nodes_folder = "26-05-2022--14-00-54-louvain-10000" 
df = create_graph(date_10000_nodes_folder)
create_comparison_plot(df, algo_index=0, plot_name="modularity: comparison")
df = create_graph(date_10000_nodes_folder, ev_col="jaccard", plot_name="jaccard")
create_comparison_plot(df, algo_index=0, plot_name="jaccard: comparison")
df = create_graph(date_10000_nodes_folder, ev_col="graph_accuracy", plot_name="graph_accuracy")
df = create_graph(date_10000_nodes_folder, ev_col="graph_sensitivity", plot_name="graph_sensitivity")
df = create_graph(date_10000_nodes_folder, ev_col="graph_conductance", plot_name="graph_conductance")
display(df)
# Out:
#        algo  modularity - real  modularity - algo   jaccard  \
# 0   Louvain           0.396218           0.406160  0.182675
# 1    LLP-70           0.396218           0.405728  0.194571
# 2   LLP-150           0.396218           0.405771  0.183203
# 3   Louvain           0.396054           0.405722  0.187187
# 4    LLP-70           0.396054           0.405819  0.197031
# ..      ...                ...                ...       ...
# 85   LLP-70           0.596227           0.601815  0.304883
# 86  LLP-150           0.596227           0.601663  0.308141
# 87  Louvain           0.596272           0.601772  0.299393
# 88   LLP-70           0.596272           0.601871  0.294277
# 89  LLP-150           0.596272           0.601749  0.314074
#
#     graph_conductance  graph_sensitivity  graph_accuracy  \
# 0            0.423353             0.9984        0.502688
# 1            0.421511             0.9985        0.520378
# 2            0.422493             0.9976        0.509681
# 3            0.422092             0.9976        0.515810
# 4            0.421922             0.9977        0.524372
# ..                ...                ...             ...
# 85           0.612167             1.0000        0.628888
# 86           0.612135             1.0000        0.633167
# 87           0.612187             1.0000        0.628172
# 88           0.612421             1.0000        0.619758
# 89           0.611749             1.0000        0.635767
#
#     num communities - real  num communities - algo num_coms_divided  \
# 0                      303                      58             None
# 1                      303                      62             None
# 2                      303                      59             None
# 3                      307                      60             None
# 4                      307                      62             None
# ..                     ...                     ...              ...
# 85                     304                      95             None
# 86                     304                      96             None
# 87                     304                      94             None
# 88                     304                      93             None
# 89                     304                      98             None
#
#    num_coms_skipped  number_of_mega_nodes  iterations    time-sec  \
# 0              None                   NaN         NaN    2.767486
# 1              None                  62.0         3.0    4.796015
# 2              None                 106.0         2.0  311.397457
# 3              None                   NaN         NaN    2.201684
# 4              None                  62.0         3.0    4.736283
# ..              ...                   ...         ...         ...
# 85             None                  95.0         3.0    8.646558
# 86             None                 107.0         2.0   18.646255
# 87             None                   NaN         NaN    1.929988
# 88             None                  93.0         3.0    8.107018
# 89             None                 104.0         2.0   14.870665
#
#         network   mu
# 0   10000_0.6_9  0.6
# 1   10000_0.6_9  0.6
# 2   10000_0.6_9  0.6
# 3   10000_0.6_8  0.6
# 4   10000_0.6_8  0.6
# ..          ...  ...
# 85  10000_0.4_1  0.4
# 86  10000_0.4_1  0.4
# 87  10000_0.4_0  0.4
# 88  10000_0.4_0  0.4
# 89  10000_0.4_0  0.4
#
# [90 rows x 16 columns]

# %% [markdown]
# # Louvain - 1,000 nodes

# %%
date_10000_nodes_folder = "26-05-2022--15-13-20-louvain-1000"
df = create_graph(date_10000_nodes_folder)
create_comparison_plot(df, algo_index=0, plot_name="modularity: comparison")
df = create_graph(date_10000_nodes_folder, ev_col="jaccard", plot_name="jaccard")
create_comparison_plot(df, algo_index=0, plot_name="jaccard: comparison")
df = create_graph(date_10000_nodes_folder, ev_col="graph_accuracy", plot_name="graph_accuracy")
df = create_graph(date_10000_nodes_folder, ev_col="graph_sensitivity", plot_name="graph_sensitivity")
df = create_graph(date_10000_nodes_folder, ev_col="graph_conductance", plot_name="graph_conductance")
display(df)
# Out:
#         algo  modularity - real  modularity - algo   jaccard  \
# 0    Louvain           0.363148           0.359769  0.514590
# 1    LLP-100           0.363148           0.360630  0.476668
# 2    LLP-100           0.363148           0.366264  0.590537
# 3    LLP-100           0.363148           0.360157  0.553905
# 4    LLP-100           0.363148           0.361996  0.519911
# ..       ...                ...                ...       ...
# 325  LLP-100           0.564733           0.565410  0.886834
# 326  LLP-100           0.564733           0.565410  0.886834
# 327  LLP-100           0.564733           0.565410  0.886834
# 328  LLP-100           0.564733           0.565410  0.886834
# 329  LLP-100           0.564733           0.565410  0.886834
#
#      graph_conductance  graph_sensitivity  graph_accuracy  \
# 0             0.414455              0.974        0.827479
# 1             0.419483              0.972        0.800342
# 2             0.417554              0.981        0.844504
# 3             0.410523              0.956        0.839388
# 4             0.418192              0.973        0.812814
# ..                 ...                ...             ...
# 325           0.603145              1.000        0.965919
# 326           0.603145              1.000        0.965919
# 327           0.603145              1.000        0.965919
# 328           0.603145              1.000        0.965919
# 329           0.603145              1.000        0.965919
#
#      num communities - real  num communities - algo num_coms_divided  \
# 0                        30                      20             None
# 1                        30                      19             None
# 2                        30                      20             None
# 3                        30                      21             None
# 4                        30                      19             None
# ..                      ...                     ...              ...
# 325                      31                      28             None
# 326                      31                      28             None
# 327                      31                      28             None
# 328                      31                      28             None
# 329                      31                      28             None
#
#     num_coms_skipped  number_of_mega_nodes  iterations  time-sec     network  \
# 0               None                   NaN         NaN  0.170578  1000_0.6_9
# 1               None                  31.0         1.0  0.620861  1000_0.6_9
# 2               None                  35.0         1.0  0.735362  1000_0.6_9
# 3               None                  32.0         1.0  0.699961  1000_0.6_9
# 4               None                  35.0         1.0  0.660898  1000_0.6_9
# ..               ...                   ...         ...       ...         ...
# 325             None                  33.0         1.0  0.573977  1000_0.4_0
# 326             None                  31.0         1.0  0.407282  1000_0.4_0
# 327             None                  32.0         1.0  0.498012  1000_0.4_0
# 328             None                  32.0         1.0  0.505108  1000_0.4_0
# 329             None                  35.0         1.0  0.602519  1000_0.4_0
#
#       mu
# 0    0.6
# 1    0.6
# 2    0.6
# 3    0.6
# 4    0.6
# ..   ...
# 325  0.4
# 326  0.4
# 327  0.4
# 328  0.4
# 329  0.4
#
# [330 rows x 16 columns]
